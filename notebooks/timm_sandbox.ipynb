# %%
import timm
import torch

# %%
timm.list_models('resnet*')
# Out:
# ['resnet10t',
#  'resnet14t',
#  'resnet18',
#  'resnet18d',
#  'resnet26',
#  'resnet26d',
#  'resnet26t',
#  'resnet32ts',
#  'resnet33ts',
#  'resnet34',
#  'resnet34d',
#  'resnet50',
#  'resnet50_clip',
#  'resnet50_clip_gap',
#  'resnet50_gn',
#  'resnet50_mlp',
#  'resnet50c',
#  'resnet50d',
#  'resnet50s',
#  'resnet50t',
#  'resnet50x4_clip',
#  'resnet50x4_clip_gap',
#  'resnet50x16_clip',
#  'resnet50x16_clip_gap',
#  'resnet50x64_clip',
#  'resnet50x64_clip_gap',
#  'resnet51q',
#  'resnet61q',
#  'resnet101',
#  'resnet101_clip',
#  'resnet101_clip_gap',
#  'resnet101c',
#  'resnet101d',
#  'resnet101s',
#  'resnet152',
#  'resnet152c',
#  'resnet152d',
#  'resnet152s',
#  'resnet200',
#  'resnet200d',
#  'resnetaa34d',
#  'resnetaa50',
#  'resnetaa50d',
#  'resnetaa101d',
#  'resnetblur18',
#  'resnetblur50',
#  'resnetblur50d',
#  'resnetblur101d',
#  'resnetrs50',
#  'resnetrs101',
#  'resnetrs152',
#  'resnetrs200',
#  'resnetrs270',
#  'resnetrs350',
# ...

# %%
m = timm.create_model('resnet34', pretrained=True, in_chans=1)

# single channel image
x = torch.randn(1, 1, 224, 224)

m(x).shape
# Out:
# torch.Size([1, 1000])

# %%
m = timm.create_model('resnetv2_18')

# single channel image
x = torch.randn(1, 3, 224, 224)

m(x).shape
# Out:
# torch.Size([1, 1000])
